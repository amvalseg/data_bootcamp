# %% [markdown]
# # 🚀 Guía Completa: Atajos de Teclado en Visual Studio Code
#
# ## 📋 Tabla de Contenidos
# 1. [Atajos Esenciales de VS Code](#atajos-esenciales-de-vs-code)
# 2. [Navegación y Búsqueda](#navegación-y-búsqueda)
# 3. [Edición de Código](#edición-de-código)
# 4. [Gestión de Archivos](#gestión-de-archivos)
# 5. [Terminal y Debug](#terminal-y-debug)
# 6. [Atajos Específicos para Jupyter Notebooks](#atajos-específicos-para-jupyter-notebooks)
# 7. [Modo Comando vs Modo Edición en Jupyter](#modo-comando-vs-modo-edición-en-jupyter)
# 8. [Tips Avanzados](#tips-avanzados)
#
# ---
#
# ## 🎯 Atajos Esenciales de VS Code
#
# ### Command Palette y Configuración
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + Shift + P` | Command Palette | Tu mejor amigo - acceso a todas las funciones |
# | `Ctrl + ,` | Settings | Abrir configuración |
# | `Ctrl + K, Ctrl + T` | Change Theme | Cambiar tema de colores |
# | `Ctrl + K, Z` | Zen Mode | Modo concentración sin distracciones |
# | `F11` | Toggle Fullscreen | Pantalla completa |
#
# ### Atajos de Archivo Básicos
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + N` | New File | Crear archivo nuevo |
# | `Ctrl + O` | Open File | Abrir archivo |
# | `Ctrl + S` | Save | Guardar archivo |
# | `Ctrl + Shift + S` | Save As | Guardar como |
# | `Ctrl + W` | Close Tab | Cerrar pestaña actual |
# | `Ctrl + Shift + T` | Reopen Tab | Reabrir última pestaña cerrada |
#
# ---
#
# ## 🔍 Navegación y Búsqueda
#
# ### Búsqueda de Archivos y Contenido
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + P` | Quick Open | Buscar y abrir archivos rápidamente |
# | `Ctrl + F` | Find | Buscar en archivo actual |
# | `Ctrl + H` | Replace | Buscar y reemplazar |
# | `Ctrl + Shift + F` | Find in Files | Buscar en todos los archivos |
# | `Ctrl + Shift + H` | Replace in Files | Reemplazar en todos los archivos |
# | `F3` / `Shift + F3` | Next/Previous Match | Siguiente/anterior coincidencia |
#
# ### Navegación en el Código
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + G` | Go to Line | Ir a línea específica |
# | `F12` | Go to Definition | Ir a definición |
# | `Alt + F12` | Peek Definition | Ver definición sin cambiar archivo |
# | `Shift + F12` | Find References | Encontrar todas las referencias |
# | `Ctrl + Shift + O` | Go to Symbol | Navegar por símbolos del archivo |
# | `Ctrl + T` | Go to Symbol in Workspace | Buscar símbolos en todo el proyecto |
#
# ---
#
# ## ✏️ Edición de Código
#
# ### Selección y Multi-cursor
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Alt + Click` | Add Cursor | Agregar cursor adicional |
# | `Ctrl + D` | Select Next Match | Seleccionar siguiente coincidencia |
# | `Ctrl + Shift + L` | Select All Matches | Seleccionar todas las coincidencias |
# | `Alt + Shift + I` | Insert Cursors at Line Ends | Cursor al final de líneas seleccionadas |
# | `Ctrl + A` | Select All | Seleccionar todo |
# | `Shift + Alt + →/←` | Expand/Shrink Selection | Expandir/contraer selección |
#
# ### Manipulación de Líneas
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + X` | Cut Line | Cortar línea completa |
# | `Ctrl + C` | Copy Line | Copiar línea completa |
# | `Shift + Alt + ↑/↓` | Copy Line Up/Down | Duplicar línea arriba/abajo |
# | `Alt + ↑/↓` | Move Line Up/Down | Mover línea arriba/abajo |
# | `Ctrl + Shift + K` | Delete Line | Eliminar línea completa |
# | `Ctrl + Enter` | Insert Line Below | Nueva línea abajo |
# | `Ctrl + Shift + Enter` | Insert Line Above | Nueva línea arriba |
#
# ### Comentarios e Indentación
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + /` | Toggle Line Comment | Comentar/descomentar línea |
# | `Shift + Alt + A` | Toggle Block Comment | Comentario de bloque |
# | `Ctrl + ]` / `Ctrl + [` | Indent/Outdent | Indentar/desindentar |
# | `Tab` / `Shift + Tab` | Indent/Outdent Selection | Indentar/desindentar selección |
#
# ---
#
# ## 📁 Gestión de Archivos
#
# ### Explorer y Pestañas
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + Shift + E` | Toggle Explorer | Mostrar/ocultar explorador de archivos |
# | `Ctrl + Tab` | Switch Between Tabs | Cambiar entre pestañas |
# | `Ctrl + PageUp/PageDown` | Previous/Next Tab | Pestaña anterior/siguiente |
# | `Ctrl + \` | Split Editor | Dividir editor |
# | `Ctrl + 1/2/3` | Focus Editor Group | Enfocar grupo de editor |
#
# ---
#
# ## 🖥️ Terminal y Debug
#
# ### Terminal Integrado
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Ctrl + `` | Toggle Terminal | Mostrar/ocultar terminal |
# | `Ctrl + Shift + `` | New Terminal | Nuevo terminal |
# | `Ctrl + Shift + C` | Open External Terminal | Abrir terminal externo |
#
# ### Debug y Ejecución
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `F5` | Start Debugging | Iniciar debug |
# | `Shift + F5` | Stop Debugging | Detener debug |
# | `F9` | Toggle Breakpoint | Alternar punto de interrupción |
# | `F10` | Step Over | Paso por encima |
# | `F11` | Step Into | Paso dentro |
#
# ---
#
# ## 📓 Atajos Específicos para Jupyter Notebooks
#
# ### Ejecución de Celdas
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `Shift + Enter` | Run Cell and Select Next | Ejecutar celda y pasar a la siguiente |
# | `Ctrl + Enter` | Run Cell | Ejecutar celda actual |
# | `Alt + Enter` | Run Cell and Insert Below | Ejecutar y crear nueva celda abajo |
# | `Ctrl + Shift + A` | Run All Cells | Ejecutar todas las celdas |
# | `Ctrl + Shift + R` | Restart Kernel | Reiniciar kernel |
#
# ### Navegación en Notebooks
# | Atajo | Función | Descripción |
# |-------|---------|-------------|
# | `↑/↓` | Navigate Cells | Navegar entre celdas (modo comando) |
# | `A` | Insert Cell Above | Insertar celda arriba |
# | `B` | Insert Cell Below | Insertar celda abajo |
# | `DD` | Delete Cell | Eliminar celda (presionar D dos veces) |
# | `Z` | Undo Cell Operation | Deshacer operación de celda |
# | `M` | Change to Markdown | Cambiar a celda Markdown |
# | `Y` | Change to Code | Cambiar a celda de código |
#
# ---
#
# ## 🎛️ Modo Comando vs Modo Edición en Jupyter
#
# ### 🔵 Modo Comando (Celda seleccionada con borde azul)
# En este modo puedes manipular celdas pero no editar su contenido.
#
# **Para entrar en Modo Comando:**
# - Presiona `Esc`
# - Haz click fuera del área de texto de la celda
#
# **Atajos disponibles en Modo Comando:**
# | Atajo | Función |
# |-------|---------|
# | `Enter` | Entrar en modo edición |
# | `A` | Insertar celda arriba |
# | `B` | Insertar celda abajo |
# | `DD` | Eliminar celda |
# | `M` | Cambiar a Markdown |
# | `Y` | Cambiar a código |
# | `C` | Copiar celda |
# | `V` | Pegar celda |
# | `X` | Cortar celda |
# | `Z` | Deshacer |
# | `Shift + Z` | Rehacer |
#
# ### 🟢 Modo Edición (Cursor dentro de la celda)
# En este modo puedes editar el contenido de la celda.
#
# **Para entrar en Modo Edición:**
# - Presiona `Enter`
# - Haz doble click en la celda
# - Haz click dentro del área de texto
#
# **Atajos disponibles en Modo Edición:**
# | Atajo | Función |
# |-------|---------|
# | `Esc` | Salir a modo comando |
# | `Tab` | Autocompletar |
# | `Shift + Tab` | Mostrar documentación |
# | `Ctrl + /` | Comentar línea |
# | `Ctrl + A` | Seleccionar todo |
#
# ---
#
# ## 💡 Tips Avanzados
#
# ### Configuraciones Útiles
# ```json
# // Para agregar a settings.json (Ctrl + Shift + P → "Open Settings JSON")
# {
#     "editor.formatOnSave": true,
#     "files.autoSave": "afterDelay",
#     "editor.minimap.enabled": true,
#     "workbench.colorTheme": "Dark+ (default dark)",
#     "editor.fontSize": 14,
#     "terminal.integrated.fontSize": 14
# }
# ```
#
# ### Extensiones Recomendadas
# - **Jupyter** - Soporte completo para notebooks
# - **Python** - IntelliSense y debugging para Python
# - **Prettier** - Formateo automático
# - **GitLens** - Integración avanzada con Git
# - **Auto Rename Tag** - Renombrado automático de tags HTML
#
# ### Trucos de Productividad
#
# 1. **Snippets personalizados:** Crea fragmentos de código reutilizables
# 2. **Tasks:** Automatiza tareas repetitivas con `tasks.json`
# 3. **Multi-root workspaces:** Trabaja con múltiples proyectos simultáneamente
# 4. **Settings Sync:** Sincroniza configuración entre dispositivos
#
# ---
#
# ## 🎯 Resumen: Atajos Imprescindibles
#
# ### Los 10 atajos que DEBES memorizar:
# 1. `Ctrl + Shift + P` - Command Palette
# 2. `Ctrl + P` - Quick Open
# 3. `Ctrl + S` - Save
# 4. `Shift + Enter` - Run Jupyter Cell
# 5. `Ctrl + D` - Select Next Match
# 6. `Alt + ↑/↓` - Move Line
# 7. `Ctrl + /` - Comment Line
# 8. `Ctrl + F` - Find
# 9. `Ctrl + `` - Toggle Terminal
# 10. `F12` - Go to Definition
#
# > **💡 Tip Final:** No intentes memorizar todos los atajos de una vez. Practica con 2-3 nuevos cada semana hasta que se vuelvan automáticos.
#
# ---
#
# *📚 Para más información, consulta la [documentación oficial de VS Code](https://code.visualstudio.com/docs)*
